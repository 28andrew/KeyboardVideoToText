# %%
import os
from argparse import Namespace

from datasets import load_dataset

DATA_DIR = "../0data_collection/keystroke-typing-videos"
dataset = load_dataset(
    "json",
    data_files={
        "train":      os.path.join(DATA_DIR, "train",      "metadata.jsonl"),
        "validation": os.path.join(DATA_DIR, "validation", "metadata.jsonl"),
        "test":       os.path.join(DATA_DIR, "test",       "metadata.jsonl"),
    },
    field=None,  # top-level JSONL
)

dataset
# Out:
# Using custom data configuration default-e2f6fbf577b386e0
# Downloading and preparing dataset json/default to /Users/andrewtran/.cache/huggingface/datasets/json/default-e2f6fbf577b386e0/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /Users/andrewtran/.cache/huggingface/datasets/json/default-e2f6fbf577b386e0/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#         num_rows: 640
#     })
#     validation: Dataset({
#         features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#         num_rows: 80
#     })
#     test: Dataset({
#         features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#         num_rows: 80
#     })
# })

# %%
sample = dataset['train'][0]

# %%
def preprocess(ex, split):
    video_path = os.path.join(DATA_DIR, split, ex["file_name"])
    prompt     = f"<Video>{video_path}</Video>\nGive me the exact string that is being typed in the video."
    return {"prompt": prompt, "completion": ex["text"]}

# %%
preprocess(sample, 'train')
# Out:
# {'prompt': '<Video>../0data_collection/keystroke-typing-videos/train/758.mp4</Video>\nGive me the exact string that is being typed in the video.',
#  'completion': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.'}

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#     num_rows: 640
# })

# %% [markdown]
# # Data Augmentation

# %%
dataset['train'][0]
# Out:
# {'file_name': '758.mp4',
#  'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#  'duration_sec': 11.5,
#  'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#   {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#   {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#   {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#   {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#   {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#   {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#   {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#  'actual_fps': 29.44422979322071}

# %%
def add_file_path(example, split):
    example['file_path'] = os.path.join(DATA_DIR, split, example['file_name'])
    return example

for split in ['train', 'validation', 'test']:
    dataset[split] = dataset[split].map(lambda x: add_file_path(x, split))
# Out:
# Parameter 'function'=<function <lambda> at 0x106a53420> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
#   0%|          | 0/640 [00:00<?, ?ex/s]
#   0%|          | 0/80 [00:00<?, ?ex/s]
#   0%|          | 0/80 [00:00<?, ?ex/s]

# %%
sample = dataset['train'][0]
sample
# Out:
# {'file_name': '758.mp4',
#  'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#  'duration_sec': 11.5,
#  'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#   {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#   {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#   {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#   {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#   {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#   {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#   {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#  'actual_fps': 29.44422979322071,
#  'file_path': '../0data_collection/keystroke-typing-videos/train/758.mp4'}

# %%
import string
import math
import random
import subprocess
import copy

AUG_DIR = os.path.join(DATA_DIR, "train_aug")
os.makedirs(AUG_DIR, exist_ok=True)

def clip_video(original_video_path, new_video_path, start_ms, end_ms):
    start_sec = start_ms / 1000
    duration_sec = (end_ms - start_ms) / 1000

    # ffmpeg command to trim the video
    cmd = [
        "ffmpeg",
        "-y",  # Overwrite without asking
        "-ss", str(start_sec),        # Start time
        "-i", original_video_path,    # Input file
        "-t", str(duration_sec),      # Duration
        "-c", "copy",                 # Copy codec to avoid re-encoding
        new_video_path                # Output file
    ]

    subprocess.run(cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Plan is that we have
# - 640 normal
# - Each normal sample gets 8 augmented versions (4 full length augment, 4 crops + augment)
def create_crop(sample, aug_idx: int, crop_size: float):
    orig_idx_str = os.path.basename(sample['file_path']).split(".")[0]
    original_video_path = sample["file_path"]
    new_video_path = os.path.join(AUG_DIR, f"{orig_idx_str}.crop_{aug_idx}.mp4")

    keystrokes = sample['keystrokes']
    keystroke_count = len(keystrokes)
    range_len = max(1, math.floor(crop_size * keystroke_count))
    start = random.randint(0, keystroke_count - range_len)
    end = start + range_len

    start_timestamp_ms = keystrokes[start]['timestamp_ms']
    end_timestamp_ms = keystrokes[min(end + 1, len(keystrokes) - 1)]['timestamp_ms']

    new_keystrokes = copy.deepcopy(keystrokes[start:end+1])
    new_text = ""
    for keystroke in new_keystrokes:
        if keystroke['key'] == 'space':
            new_text += ' '
        elif len(keystroke['key']) == 1 and (keystroke['key'].isalnum() or keystroke['key'] in string.punctuation):
            new_text += keystroke['key']

    clip_video(original_video_path, new_video_path, start_timestamp_ms, end_timestamp_ms)

    # Re-zero the timestamps
    for keystroke in new_keystrokes:
        keystroke['timestamp_ms'] -= start_timestamp_ms

    return {
        'file_path': new_video_path,
        'text': new_text,
        'duration_sec': (end_timestamp_ms - start_timestamp_ms) / 1000,
        'keystrokes': new_keystrokes,
        'actual_fps': sample['actual_fps']
    }

# %%
create_crop(sample, 0, 0.3)
# Out:
# {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_0.mp4',
#  'text': 's predominantly in southern ',
#  'duration_sec': 3.581,
#  'keystrokes': [{'event': 'down', 'key': 's', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 56},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 205},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 302},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 370},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 516},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 545},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 701},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 862},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1007},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1184},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1402},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 1653},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 1832},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 1983},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2084},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 2176},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 2313},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2384},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2481},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 2579},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 2714},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 2824},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 3019},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 3181},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 3292},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 3372},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3469},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 3535}],
#  'actual_fps': 29.44422979322071}

# %%
import os
import copy
import cv2
import numpy as np
import random
import subprocess

AUG_DIR = "../0data_collection/keystroke-typing-videos/train_aug"
os.makedirs(AUG_DIR, exist_ok=True)

def create_aug(sample, aug_idx: int):
    orig_fp = sample["file_path"]
    base    = os.path.splitext(os.path.basename(orig_fp))[0]
    tmp_fp  = os.path.join(AUG_DIR, f"{base}.aug_{aug_idx}.tmp.mp4")
    new_fp  = os.path.join(AUG_DIR, f"{base}.aug_{aug_idx}.mp4")

    # 1) write the tmp video
    cap = cv2.VideoCapture(orig_fp)
    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0
    w   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h   = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(tmp_fp, fourcc, fps, (w, h))

    # random augmentation params
    k      = random.choice([1,3])
    angle  = random.uniform(-5,5)
    scale  = random.uniform(0.9,1.1)
    tx     = random.uniform(-0.05,0.05)*w
    ty     = random.uniform(-0.05,0.05)*h
    max_pw = 0.1*min(w,h)
    src    = np.float32([[0,0],[w,0],[w,h],[0,h]])
    dst    = src + np.random.uniform(-max_pw,max_pw,(4,2)).astype(np.float32)
    M_p    = cv2.getPerspectiveTransform(src,dst)
    M_r    = cv2.getRotationMatrix2D((w/2,h/2), angle, scale)
    M_r[0,2] += tx
    M_r[1,2] += ty

    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.GaussianBlur(frame,(k,k),0)
        frame = cv2.warpPerspective(frame, M_p, (w,h), borderMode=cv2.BORDER_REFLECT)
        frame = cv2.warpAffine(frame, M_r, (w,h), borderMode=cv2.BORDER_REFLECT)
        out.write(frame)
        frame_count += 1

    cap.release()
    out.release()

    cmd = [
        "ffmpeg", "-y",
        "-i", tmp_fp,        # video‐only file
        "-i", orig_fp,       # original has audio+video
        "-c:v", "libx264", "-preset", "ultrafast",
        "-c:a", "copy",      # copy the audio stream from orig_fp
        new_fp
    ]
    # print("Running FFmpeg:", " ".join(cmd))
    proc = subprocess.run(cmd, capture_output=True, text=True)
    # print(proc.stderr)       # look for any warnings/errors
    proc.check_returncode()  # raises if ffmpeg failed

    # Clean up
    os.remove(tmp_fp)

    # 4) Verify
    if not os.path.exists(new_fp):
        raise FileNotFoundError(f"Final augmented file not found at {new_fp}")

    new_sample = copy.copy(sample)
    new_sample["file_path"] = new_fp
    return new_sample

# %%
create_aug(sample, 0)
# Out:
# {'file_name': '758.mp4',
#  'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#  'duration_sec': 11.5,
#  'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#   {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#   {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#   {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#   {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#   {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#   {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#   {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#  'actual_fps': 29.44422979322071,
#  'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_0.mp4'}

# %%
final_samples = []

# %%
cropped = create_crop(sample, 0, 0.3)
aug_cropped = create_aug(cropped, 0)
aug_cropped
# Out:
# {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_0.aug_0.mp4',
#  'text': 'es predominantly in southern ',
#  'duration_sec': 3.692,
#  'keystrokes': [{'event': 'down', 'key': 'e', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 157},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 213},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 362},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 459},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 527},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 673},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 702},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 858},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 1019},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1164},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1341},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1559},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 1810},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 1989},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 2140},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2241},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 2333},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 2470},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2541},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2638},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 2736},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 2871},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 2981},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 3176},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 3338},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 3449},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 3529},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3626}],
#  'actual_fps': 29.44422979322071}

# %%
import os
CROP_SIZE = 0.3

train_split = list(dataset["train"])

def process_one(args):
    """
    Given (sample, idx), produce:
      - the original sample
      - 8 crop+aug variants (j=0..7)
      - 8 full-length aug variants (j=8..15)
    """
    sample, idx = args
    out = []
    # 1) original
    out.append(sample)
    # 2) crop + augment
    for j in range(8):
        cropped = create_crop(sample, j, CROP_SIZE)
        aug_cropped = create_aug(cropped, j)
        out.append(aug_cropped)
    # 3) full-length augment
    for j in range(8, 16):
        out.append(create_aug(sample, j))
    return out

process_one((sample, 0))
# Out:
# [{'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train/758.mp4'},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_0.aug_0.mp4',
#   'text': ' and 91 branches predominantl',
#   'duration_sec': 3.456,
#   'keystrokes': [{'event': 'down', 'key': 'space', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 74},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 143},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 235},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 316},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 426},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 501},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 577},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 668},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 773},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 929},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1019},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 1135},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 1280},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 1316},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1473},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 1678},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 1775},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 1843},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 1989},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 2018},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 2174},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2335},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2480},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2657},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2875},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 3126},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3305}],
#   'actual_fps': 29.44422979322071},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_1.aug_1.mp4',
#   'text': 'ts and 91 branches predominan',
#   'duration_sec': 3.426,
#   'keystrokes': [{'event': 'down', 'key': 't', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 189},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 300},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 374},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 443},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 535},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 616},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 726},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 801},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 877},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 968},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 1073},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1229},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1319},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 1435},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 1580},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 1616},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1773},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1829},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 1978},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 2075},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 2143},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 2289},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 2318},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 2474},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2635},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2780},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2957},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 3175}],
#   'actual_fps': 29.44422979322071},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_2.aug_2.mp4',
#   'text': ' Savings has 66 billion in ',
#   'duration_sec': 3.752,
#   'keystrokes': [{'event': 'down', 'key': 'space', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 98},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 237},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 371},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 540},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 629},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 782},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 810},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 980},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1048},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 1134},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1186},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1270},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1371},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2080},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 2169},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2300},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2364},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 2492},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2560},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 2725},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 2856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3000},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 3142},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 3286},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3359},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3485},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 3605},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3658}],
#   'actual_fps': 29.44422979322071},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_3.aug_3.mp4',
#   'text': 's predominantly in southern ',
#   'duration_sec': 3.581,
#   'keystrokes': [{'event': 'down', 'key': 's', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 56},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 205},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 302},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 370},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 516},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 545},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 701},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 862},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1007},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1184},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1402},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 1653},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 1832},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 1983},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2084},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2176},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2313},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2384},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2481},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 2579},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 2714},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 2824},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 3019},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 3181},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 3292},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 3372},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3469},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 3535}],
#   'actual_fps': 29.44422979322071},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_4.aug_4.mp4',
#   'text': '66 billion in assets and 91 ',
#   'duration_sec': 3.232,
#   'keystrokes': [{'event': 'down', 'key': '6', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 89},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 220},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 284},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 412},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 480},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 645},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 776},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 920},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 1062},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1206},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1279},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1405},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1525},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1578},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1672},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1772},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1956},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 2164},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 2264},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2453},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2564},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2638},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2707},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 2799},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2880},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 2990},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 3065},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3141}],
#   'actual_fps': 29.44422979322071},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_5.aug_5.mp4',
#   'text': 'avings has 66 billion in ass',
#   'duration_sec': 3.873,
#   'keystrokes': [{'event': 'down', 'key': 'a', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 169},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 258},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 411},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 439},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 609},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 677},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 763},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 815},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 899},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1000},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 1709},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 1798},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 1929},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1993},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 2121},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2189},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 2354},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 2485},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2629},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 2771},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2915},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2988},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3114},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 3234},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3287},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 3381},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 3481},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 3665}],
#   'actual_fps': 29.44422979322071},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_6.aug_6.mp4',
#   'text': 'ominantly in southern Califo',
#   'duration_sec': 3.738,
#   'keystrokes': [{'event': 'down', 'key': 'o', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 156},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 317},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 462},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 639},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 857},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 1108},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 1287},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 1438},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1539},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1631},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1768},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1839},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1936},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 2169},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 2279},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2474},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 2636},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 2747},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2827},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2924},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 2990},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 3036},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 3153},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3294},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3440},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 3514},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 3634}],
#   'actual_fps': 29.44422979322071},
#  {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_7.aug_7.mp4',
#   'text': 'gs has 66 billion in assets ',
#   'duration_sec': 3.908,
#   'keystrokes': [{'event': 'down', 'key': 'g', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 238},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 324},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 376},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 460},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 561},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 1270},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 1359},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 1490},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1554},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1750},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 1915},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 2046},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2190},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 2332},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2476},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2549},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 2675},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 2795},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2848},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2942},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 3042},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 3226},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 3434},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 3534},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 3723},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3834}],
#   'actual_fps': 29.44422979322071},
#  {'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_8.mp4'},
#  {'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_9.mp4'},
#  {'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_10.mp4'},
#  {'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_11.mp4'},
#  {'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
# ...
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_13.mp4'},
#  {'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_14.mp4'},
#  {'file_name': '758.mp4',
#   'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#   'duration_sec': 11.5,
#   'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#    {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#    {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#    {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#    {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#    {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#    {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#    {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#    {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#    {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#    {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#    {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#    {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#    {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#    {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#   'actual_fps': 29.44422979322071,
#   'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_15.mp4'}]

# %%
# !rm -rf {AUG_DIR}/*

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.notebook import tqdm

CROP_SIZE = 0.3
train_split = list(dataset["train"])

def _worker(task):
    sample, idx = task
    return process_one((sample, idx))

tasks = [(s, i) for i, s in enumerate(train_split)]

final_samples = []
max_workers = 8

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = {executor.submit(_worker, t): t for t in tasks}
    for future in tqdm(as_completed(futures),
                       total=len(futures),
                       desc="Augmenting"):
        sample, idx = futures[future]
        try:
            batch = future.result()
            final_samples.extend(batch)
        except Exception as e:
            print(f"Error processing sample {idx}: {e}")

print(f"Done — produced {len(final_samples)} samples")
# Out:
# Augmenting:   0%|          | 0/640 [00:00<?, ?it/s]
# Error processing sample 28: Command '['ffmpeg', '-y', '-i', '../0data_collection/keystroke-typing-videos/train_aug/313.crop_1.aug_1.tmp.mp4', '-i', '../0data_collection/keystroke-typing-videos/train_aug/313.crop_1.mp4', '-c:v', 'libx264', '-preset', 'ultrafast', '-c:a', 'copy', '../0data_collection/keystroke-typing-videos/train_aug/313.crop_1.aug_1.mp4']' returned non-zero exit status 183.
# Error processing sample 29: Command '['ffmpeg', '-y', '-i', '../0data_collection/keystroke-typing-videos/train_aug/437.aug_8.tmp.mp4', '-i', '../0data_collection/keystroke-typing-videos/train/437.mp4', '-c:v', 'libx264', '-preset', 'ultrafast', '-c:a', 'copy', '../0data_collection/keystroke-typing-videos/train_aug/437.aug_8.mp4']' returned non-zero exit status 254.
# Done — produced 10846 samples

# %%
import pickle

with open('final_samples.pkl', 'wb') as f:
    pickle.dump(final_samples, f)

# %%
import pickle

with open('final_samples.pkl', 'rb') as f:
    final_samples = pickle.load(f)

# %%
import os

DATASETS_PATH = 'LLaMA-Factory/data'
DATASET_INFO_PATH = os.path.join(DATASETS_PATH, 'dataset_info.json')
DATASET_JSON_PATH = os.path.join(DATASETS_PATH, 'keyboard.json')

# %%
# Add my dataset
import json

new_entry_key = "keyboard"
new_entry_value = {
    'file_name': 'keyboard.json',
    'formatting': 'sharegpt',
    'columns': {
        'messages': 'messages',
        'videos': 'videos',
        'audios': 'audios'
    },
    'tags': {
        'role_tag': 'role',
        'content_tag': 'content',
        'user_tag': 'user',
        'assistant_tag': 'assistant'
    }
}

with open(DATASET_INFO_PATH, 'r') as f:
    data = json.load(f)

data[new_entry_key] = new_entry_value

with open(DATASET_INFO_PATH, 'w') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# %%
# Copy videos
# !mkdir -p {DATASETS_PATH}/keyboard_videos

# %%
# !rsync -a {AUG_DIR}/../train/ {DATASETS_PATH}/keyboard_videos/
# Out:
# rsync: setpgid: Operation not permitted

# %%
# !rsync -r --include='*.mp4' --exclude='*' {AUG_DIR} {DATASETS_PATH}/keyboard_videos/
# Out:
# rsync: setpgid: Operation not permitted

# %%
# %%bash
# cd LLaMA-Factory/data/keyboard_videos
# parallel --bar -j32 \
#   ffmpeg -y -i {} -vn -acodec pcm_s16le -ar 16000 -ac 1 {.}.wav \
#   ::: *.mp4
# Out:
# m #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1271 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 197 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.aug_8.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600002c94000] video:0KiB audio:150KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.050781%
# size=     150KiB time=00:00:04.80 bitrate= 256.1kbits/s speed=1.21e+03x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.aug_9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:04.80, start: 0.000000, bitrate: 1623 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1415 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 197 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.aug_9.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600001c94000] video:0KiB audio:150KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.050781%
# size=     150KiB time=00:00:04.80 bitrate= 256.1kbits/s speed=1.22e+03x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_0.aug_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.57, start: 0.000000, bitrate: 1968 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1614 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 208 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_0.aug_0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600002c64000] video:0KiB audio:48KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.160362%
# size=      48KiB time=00:00:01.52 bitrate= 256.4kbits/s speed= 712x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.69, start: 0.000000, bitrate: 2653 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 883 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 199 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003aa0000] video:0KiB audio:48KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.160362%
# size=      48KiB time=00:00:01.52 bitrate= 256.4kbits/s speed= 650x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_1.aug_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.77, start: 0.000000, bitrate: 1641 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1449 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 185 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_1.aug_1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003b80000] video:0KiB audio:53KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.144632%
# size=      53KiB time=00:00:01.68 bitrate= 256.4kbits/s speed= 961x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.77, start: 0.000000, bitrate: 1122 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 928 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 185 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x60000320c000] video:0KiB audio:53KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.144632%
# size=      53KiB time=00:00:01.68 bitrate= 256.4kbits/s speed= 784x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_2.aug_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.60, start: 0.000000, bitrate: 1908 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1558 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 209 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_2.aug_2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600001cf0000] video:0KiB audio:49KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.156784%
# size=      49KiB time=00:00:01.55 bitrate= 256.4kbits/s speed= 666x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.62, start: 0.000000, bitrate: 2812 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 872 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 199 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003670000] video:0KiB audio:49KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.156784%
# size=      49KiB time=00:00:01.55 bitrate= 256.4kbits/s speed= 630x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_3.aug_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.40, start: 0.000000, bitrate: 1772 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1412 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 203 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_3.aug_3.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000011bc000] video:0KiB audio:43KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.178221%
# size=      43KiB time=00:00:01.36 bitrate= 256.5kbits/s speed= 654x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.53, start: 0.000000, bitrate: 2500 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 888 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 196 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_3.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003aec000] video:0KiB audio:43KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.178221%
# size=      43KiB time=00:00:01.36 bitrate= 256.5kbits/s speed= 489x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_4.aug_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.50, start: 0.000000, bitrate: 1808 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1499 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 192 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_4.aug_4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000003bc000] video:0KiB audio:45KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.169469%
# size=      45KiB time=00:00:01.43 bitrate= 256.4kbits/s speed= 720x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.51, start: 0.000000, bitrate: 1697 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 897 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 192 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003cf4000] video:0KiB audio:45KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.169469%
# size=      45KiB time=00:00:01.43 bitrate= 256.4kbits/s speed= 603x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_5.aug_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.67, start: 0.000000, bitrate: 1569 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1316 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 190 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_5.aug_5.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600000734480] video:0KiB audio:50KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.153175%
# size=      50KiB time=00:00:01.59 bitrate= 256.4kbits/s speed= 858x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.79, start: 0.000000, bitrate: 1339 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 907 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 190 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_5.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600000bd8000] video:0KiB audio:50KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.153175%
# size=      50KiB time=00:00:01.59 bitrate= 256.4kbits/s speed= 697x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_6.aug_6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.43, start: 0.000000, bitrate: 1763 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1422 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 195 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_6.aug_6.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000000a00c0] video:0KiB audio:43KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.176927%
# size=      43KiB time=00:00:01.37 bitrate= 256.5kbits/s speed= 594x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.crop_6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:01.51, start: 0.000000, bitrate: 1923 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 885 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 193 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.crop_6.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003e9c000] video:0KiB audio:43KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.176927%
# size=      43KiB time=00:00:01.37 bitrate= 256.5kbits/s speed= 524x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
# ...
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/114.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:04.80, start: 0.000000, bitrate: 1065 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 856 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 197 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/114.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600001818000] video:0KiB audio:150KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.050781%
# size=     150KiB time=00:00:04.80 bitrate= 256.1kbits/s speed=1.17e+03x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/115.aug_10.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:08.70, start: 0.000000, bitrate: 1547 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1339 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 199 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/115.aug_10.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003cc8000] video:0KiB audio:271KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.028073%
# size=     271KiB time=00:00:08.68 bitrate= 256.1kbits/s speed=1.29e+03x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/115.aug_11.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:08.70, start: 0.000000, bitrate: 1612 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1404 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 199 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/115.aug_11.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600000964000] video:0KiB audio:271KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.028073%
# size=     271KiB time=00:00:08.68 bitrate= 256.1kbits/s speed=1e+03x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/115.aug_12.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:08.70, start: 0.000000, bitrate: 1495 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1288 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 199 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/115.aug_12.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600001858000] video:0KiB audio:271KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.028073%
# size=     271KiB time=00:00:08.68 bitrate= 256.1kbits/s speed=1.28e+03x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'LLaMA-Factory/data/keyboard_videos/115.aug_13.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:08.70, start: 0.000000, bitrate: 1643 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1435 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 199 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'LLaMA-Factory/data/keyboard_videos/wavs/115.aug_13.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600001b44000] video:0KiB audio:271KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.028073%
# size=     271KiB time=00:00:08.68 bitrate= 256.1kbits/s speed=1.24e+03x
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100

# %%
len(final_samples)
# Out:
# 10846

# %%
# %%bash
# cd LLaMA-Factory/data/keyboard_videos
# echo "Checking for corrupted or unreadable .mp4/.wav files..."
# echo "Writing plain paths to bad.txt"
# echo "----"
#
# # Clear output file
# : > bad.txt
#
# # Function to validate a single file
# check_file() {
#   file="$1"
#   duration=$(ffprobe -v error -show_entries format=duration \
#     -of default=noprint_wrappers=1:nokey=1 "$file" 2>/dev/null)
#
#   # If ffprobe fails outright
#   if [ $? -ne 0 ]; then
#     echo "$file" >> bad.txt
#     return
#   fi
#
#   # If duration is not a valid number (e.g., "N/A")
#   if ! [[ "$duration" =~ ^[0-9]+(\.[0-9]+)?$ ]]; then
#     echo "$file" >> bad.txt
#     return
#   fi
#
#   # If duration is 0 or less
#   duration_int=${duration%.*}
#   if [ "$duration_int" -le 0 ]; then
#     echo "$file" >> bad.txt
#   fi
# }
#
# # Export function for parallel
# export -f check_file
#
# # Run checks on all visible .mp4/.wav files in parallel with a progress bar
# find . -type f \( -iname "*.mp4" -o -iname "*.wav" \) ! -iname ".*" \
#   | parallel -j 16 --bar check_file {}
# cp bad.txt ../../../

# %%
bad_files = []
with open('bad.txt', 'r') as f:
    for line in f:
        bad_files.append(line.strip().replace('./', ''))
bad_files[:10]
# Out:
# ['557.crop_7.aug_7.mp4',
#  '662.aug_13.mp4',
#  '42.crop_1.aug_1.mp4',
#  '206.crop_1.mp4',
#  '744.crop_7.mp4',
#  '695.crop_4.mp4',
#  '695.crop_0.aug_0.mp4',
#  '475.aug_15.mp4',
#  '428.mp4',
#  '295.crop_5.aug_5.mp4']

# %%
import os

json_samples = []
skipped = 0
for sample in final_samples:
    file_name = os.path.basename(sample['file_path'])
    new_file_path = f'{DATASETS_PATH}/keyboard_videos/{file_name}'
    if not os.path.exists(new_file_path):
        print(f"Path {new_file_path} not found, skipping")
        continue

    if len(sample['text']) < 10:
        continue

    video_rel_path = new_file_path.replace('LLaMA-Factory/data/', '')
    audio_rel_path = video_rel_path.replace('.mp4', '.wav')

    if os.path.basename(video_rel_path) in bad_files or os.path.basename(audio_rel_path) in bad_files:
        skipped += 1
        continue

    json_sample = {
        'messages': [
            {
                'content': '<video><audio>What exact string is typed in this overhead recording of typing on a MacBook keyboard at an upside down view?',
                'role': 'user'
            },
            {
                'content': f"The typed string is: {sample['text']}",
                'role': 'assistant'
            }
        ],
        'videos': [
            video_rel_path
        ],
        'audios': [
            audio_rel_path
        ]
    }
    json_samples.append(json_sample)

with open(DATASET_JSON_PATH, 'w') as f:
    json.dump(json_samples, f, ensure_ascii=False, indent=2)

skipped, len(json_samples), json_samples[0]
# Out:
# (65,
#  10032,
#  {'messages': [{'content': '<video><audio>What exact string is typed in this overhead recording of typing on a MacBook keyboard at an upside down view?',
#     'role': 'user'},
#    {'content': 'The typed string is: This is a change of nuance.',
#     'role': 'assistant'}],
#   'videos': ['keyboard_videos/681.mp4'],
#   'audios': ['keyboard_videos/681.wav']})
