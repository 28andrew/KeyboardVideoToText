# %%
import os
from argparse import Namespace

from datasets import load_dataset

DATA_DIR = "../0data_collection/keystroke-typing-videos"
dataset = load_dataset(
    "json",
    data_files={
        "train":      os.path.join(DATA_DIR, "train",      "metadata.jsonl"),
        "validation": os.path.join(DATA_DIR, "validation", "metadata.jsonl"),
        "test":       os.path.join(DATA_DIR, "test",       "metadata.jsonl"),
    },
    field=None,  # top-level JSONL
)

dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#         num_rows: 640
#     })
#     validation: Dataset({
#         features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#         num_rows: 80
#     })
#     test: Dataset({
#         features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#         num_rows: 80
#     })
# })

# %%
sample = dataset['train'][0]

# %%
def preprocess(ex, split):
    video_path = os.path.join(DATA_DIR, split, ex["file_name"])
    prompt     = f"<Video>{video_path}</Video>\nGive me the exact string that is being typed in the video."
    return {"prompt": prompt, "completion": ex["text"]}

# %%
preprocess(sample, 'train')
# Out:
# {'prompt': '<Video>../0data_collection/keystroke-typing-videos/train/758.mp4</Video>\nGive me the exact string that is being typed in the video.',
#  'completion': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.'}

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['file_name', 'text', 'duration_sec', 'keystrokes', 'actual_fps'],
#     num_rows: 640
# })

# %% [markdown]
# # Data Augmentation

# %%
dataset['train'][0]
# Out:
# {'file_name': '758.mp4',
#  'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#  'duration_sec': 11.5,
#  'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#   {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#   {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#   {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#   {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#   {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#   {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#   {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#  'actual_fps': 29.44422979322071}

# %%
def add_file_path(example, split):
    example['file_path'] = os.path.join(DATA_DIR, split, example['file_name'])
    return example

for split in ['train', 'validation', 'test']:
    dataset[split] = dataset[split].map(lambda x: add_file_path(x, split))

# %%
sample = dataset['train'][0]
sample
# Out:
# {'file_name': '758.mp4',
#  'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#  'duration_sec': 11.5,
#  'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#   {'event': 'down', 'key': 'a', 'timestamp_ms':

#   {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#  'actual_fps': 29.44422979322071,
#  'file_path': '../0data_collection/keystroke-typing-videos/train/758.mp4'}

# %%
import string
import math
import random
import subprocess
import copy

AUG_DIR = os.path.join(DATA_DIR, "train_aug")
os.makedirs(AUG_DIR, exist_ok=True)

def clip_video(original_video_path, new_video_path, start_ms, end_ms):
    start_sec = start_ms / 1000
    duration_sec = (end_ms - start_ms) / 1000

    # ffmpeg command to trim the video
    cmd = [
        "ffmpeg",
        "-y",  # Overwrite without asking
        "-ss", str(start_sec),        # Start time
        "-i", original_video_path,    # Input file
        "-t", str(duration_sec),      # Duration
        "-c", "copy",                 # Copy codec to avoid re-encoding
        new_video_path                # Output file
    ]

    subprocess.run(cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Plan is that we have
# - 640 normal
# - Each normal sample gets 8 augmented versions (4 full length augment, 4 crops + augment)
def create_crop(sample, aug_idx: int, crop_size: float):
    orig_idx_str = os.path.basename(sample['file_path']).split(".")[0]
    original_video_path = sample["file_path"]
    new_video_path = os.path.join(AUG_DIR, f"{orig_idx_str}.crop_{aug_idx}.mp4")

    keystrokes = sample['keystrokes']
    keystroke_count = len(keystrokes)
    range_len = max(1, math.floor(crop_size * keystroke_count))
    start = random.randint(0, keystroke_count - range_len)
    end = start + range_len

    start_timestamp_ms = keystrokes[start]['timestamp_ms']
    end_timestamp_ms = keystrokes[min(end + 1, len(keystrokes) - 1)]['timestamp_ms']

    new_keystrokes = copy.deepcopy(keystrokes[start:end+1])
    new_text = ""
    for keystroke in new_keystrokes:
        if keystroke['key'] == 'space':
            new_text += ' '
        elif len(keystroke['key']) == 1 and (keystroke['key'].isalnum() or keystroke['key'] in string.punctuation):
            new_text += keystroke['key']

    clip_video(original_video_path, new_video_path, start_timestamp_ms, end_timestamp_ms)

    # Re-zero the timestamps
    for keystroke in new_keystrokes:
        keystroke['timestamp_ms'] -= start_timestamp_ms

    return {
        'file_path': new_video_path,
        'text': new_text,
        'duration_sec': (end_timestamp_ms - start_timestamp_ms) / 1000,
        'keystrokes': new_keystrokes,
        'actual_fps': sample['actual_fps']
    }

# %%
create_crop(sample, 0, 0.75)
# Out:
# {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_0.mp4',
#  'text': 'Sears Savings has 66 billion in assets and 91 branches predominantly i',
#  'duration_sec': 9.33,
#  'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#   {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#   {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#   {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#   {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#   {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 9193}],
#  'actual_fps': 29.44422979322071}

# %%
import os
import copy
import cv2
import numpy as np
import random
import subprocess

AUG_DIR = "../0data_collection/keystroke-typing-videos/train_aug"
os.makedirs(AUG_DIR, exist_ok=True)

def create_aug(sample, aug_idx: int):
    orig_fp = sample["file_path"]
    base    = os.path.splitext(os.path.basename(orig_fp))[0]
    tmp_fp  = os.path.join(AUG_DIR, f"{base}.aug_{aug_idx}.tmp.mp4")
    new_fp  = os.path.join(AUG_DIR, f"{base}.aug_{aug_idx}.mp4")

    # 1) write the tmp video
    cap = cv2.VideoCapture(orig_fp)
    fps = cap.get(cv2.CAP_PROP_FPS) or 30.0
    w   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h   = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(tmp_fp, fourcc, fps, (w, h))

    # random augmentation params
    k      = random.choice([1,3])
    angle  = random.uniform(-5,5)
    scale  = random.uniform(0.9,1.1)
    tx     = random.uniform(-0.05,0.05)*w
    ty     = random.uniform(-0.05,0.05)*h
    max_pw = 0.1*min(w,h)
    src    = np.float32([[0,0],[w,0],[w,h],[0,h]])
    dst    = src + np.random.uniform(-max_pw,max_pw,(4,2)).astype(np.float32)
    M_p    = cv2.getPerspectiveTransform(src,dst)
    M_r    = cv2.getRotationMatrix2D((w/2,h/2), angle, scale)
    M_r[0,2] += tx
    M_r[1,2] += ty

    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.GaussianBlur(frame,(k,k),0)
        frame = cv2.warpPerspective(frame, M_p, (w,h), borderMode=cv2.BORDER_REFLECT)
        frame = cv2.warpAffine(frame, M_r, (w,h), borderMode=cv2.BORDER_REFLECT)
        out.write(frame)
        frame_count += 1

    cap.release()
    out.release()

    cmd = [
        "ffmpeg", "-y",
        "-i", tmp_fp,        # video‐only file
        "-i", orig_fp,       # original has audio+video
        "-c:v", "libx264", "-preset", "ultrafast",
        "-c:a", "copy",      # copy the audio stream from orig_fp
        new_fp
    ]
    # print("Running FFmpeg:", " ".join(cmd))
    proc = subprocess.run(cmd, capture_output=True, text=True)
    # print(proc.stderr)       # look for any warnings/errors
    proc.check_returncode()  # raises if ffmpeg failed

    # Clean up
    os.remove(tmp_fp)

    # 4) Verify
    if not os.path.exists(new_fp):
        raise FileNotFoundError(f"Final augmented file not found at {new_fp}")

    new_sample = copy.copy(sample)
    new_sample["file_path"] = new_fp
    return new_sample

# %%
create_aug(sample, 0)
# Out:
# {'file_name': '758.mp4',
#  'text': 'Sears Savings has 6.6 billion in assets and 91 branches predominantly in southern California.',
#  'duration_sec': 11.5,
#  'keystrokes': [{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 253},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 436},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 541},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 648},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 803},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 900},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 998},
#   {'event': 'down', 'key': 'S', 'timestamp_ms': 1137},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 1271},
#   {'event': 'down', 'key': 'v', 'timestamp_ms': 1440},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 1529},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1682},
#   {'event': 'down', 'key': 'g', 'timestamp_ms': 1710},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 1880},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 1948},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 2034},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 2086},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 2170},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2271},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 2980},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 3069},
#   {'event': 'down', 'key': '6', 'timestamp_ms': 3200},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 3264},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 3392},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3460},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3625},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 3756},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3900},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 4042},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4186},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4259},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 4385},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 4505},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 4558},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 4652},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4752},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 4936},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 5144},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 5244},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 5433},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5544},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 5618},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 5687},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 5779},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 5860},
#   {'event': 'down', 'key': '9', 'timestamp_ms': 5970},
#   {'event': 'down', 'key': '1', 'timestamp_ms': 6045},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 6121},
#   {'event': 'down', 'key': 'b', 'timestamp_ms': 6212},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 6317},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 6473},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 6563},
#   {'event': 'down', 'key': 'c', 'timestamp_ms': 6679},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 6824},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 6860},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 7017},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 7073},
#   {'event': 'down', 'key': 'p', 'timestamp_ms': 7222},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 7319},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 7387},
#   {'event': 'down', 'key': 'd', 'timestamp_ms': 7533},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 7562},
#   {'event': 'down', 'key': 'm', 'timestamp_ms': 7718},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 7879},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8024},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 8201},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 8419},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 8670},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 8849},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 9000},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9101},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 9193},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 9330},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 9401},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 9498},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 9596},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 9731},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 9841},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 10036},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 10198},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 10309},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 10389},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 10486},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 10552},
#   {'event': 'down', 'key': 'C', 'timestamp_ms': 10598},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 10715},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 10856},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11002},
#   {'event': 'down', 'key': 'f', 'timestamp_ms': 11076},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 11196},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 11300},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 11369},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 11540},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 11613},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 11719}],
#  'actual_fps': 29.44422979322071,
#  'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.aug_0.mp4'}

# %%
final_samples = []

# %%
cropped = create_crop(sample, 0, 0.3)
aug_cropped = create_aug(cropped, 0)
aug_cropped
# Out:
# {'file_path': '../0data_collection/keystroke-typing-videos/train_aug/758.crop_0.aug_0.mp4',
#  'text': 'ntly in southern California',
#  'duration_sec': 3.3,
#  'keystrokes': [{'event': 'down', 'key': 'n', 'timestamp_ms': 0},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 251},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 430},
#   {'event': 'down', 'key': 'y', 'timestamp_ms': 581},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 682},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 774},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 911},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 982},
#   {'event': 'down', 'key': 's', 'timestamp_ms': 1079},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 1177},
#   {'event': 'down', 'key': 'u', 'timestamp_ms': 1312},
#   {'event': 'down', 'key': 't', 'timestamp_ms': 1422},
#   {'event': 'down', 'key': 'h', 'timestamp_ms': 1617},
#   {'event': 'down', 'key': 'e', 'timestamp_ms': 1779},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 1890},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 1970},
#   {'event': 'down', 'key': 'space', 'timestamp_ms': 2067},
#   {'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 2133},
#   {'event': 'down', 'key': 'C', 'timestamp_ms': 2179},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 2296},
#   {'event': 'down', 'key': 'l', 'timestamp_ms': 2437},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 2583},
#   {'event': 'down', 'key': 'f', 'timestamp_ms': 2657},
#   {'event': 'down', 'key': 'o', 'timestamp_ms': 2777},
#   {'event': 'down', 'key': 'r', 'timestamp_ms': 2881},
#   {'event': 'down', 'key': 'n', 'timestamp_ms': 2950},
#   {'event': 'down', 'key': 'i', 'timestamp_ms': 3121},
#   {'event': 'down', 'key': 'a', 'timestamp_ms': 3194},
#   {'event': 'down', 'key': 'period', 'timestamp_ms': 3300}],
#  'actual_fps': 29.44422979322071}

# %%
import os
CROP_SIZE = 0.8

train_split = list(dataset["train"])

def process_one(args):
    """
    Given (sample, idx), produce:
      - the original sample
      - 10 crop+aug variants (j=0..7)
      - 30 full-length aug variants (j=8..15)
    """
    sample, idx = args
    out = []
    # 1) original
    out.append(sample)
    # 2) crop + augment
    for j in range(10):
        cropped = create_crop(sample, j, CROP_SIZE)
        aug_cropped = create_aug(cropped, j)
        out.append(aug_cropped)
    # 3) full-length augment
    for j in range(10, 32):
        out.append(create_aug(sample, j))
    return out

# %%
# !echo {AUG_DIR}
# Out:
# ../0data_collection/keystroke-typing-videos/train_aug

# %%
# !rm -rf {AUG_DIR}/

# %%
# !mkdir {AUG_DIR}

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.notebook import tqdm

train_split = list(dataset["train"])

def _worker(task):
    sample, idx = task
    return process_one((sample, idx))

tasks = [(s, i) for i, s in enumerate(train_split)]

final_samples = []
max_workers = 10

with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = {executor.submit(_worker, t): t for t in tasks}
    for future in tqdm(as_completed(futures),
                       total=len(futures),
                       desc="Augmenting"):
        sample, idx = futures[future]
        try:
            batch = future.result()
            final_samples.extend(batch)
        except Exception as e:
            print(f"Error processing sample {idx}: {e}")

print(f"Done — produced {len(final_samples)} samples")
# Out:
# Augmenting:   0%|          | 0/640 [00:00<?, ?it/s]
# Done — produced 21120 samples

# %%
import pickle

with open('final_samples.pkl', 'wb') as f:
    pickle.dump(final_samples, f)

# %%
import pickle

with open('final_samples.pkl', 'rb') as f:
    final_samples = pickle.load(f)

# %%
import os

DATASETS_PATH = 'LLaMA-Factory/data'
DATASET_INFO_PATH = os.path.join(DATASETS_PATH, 'dataset_info.json')
DATASET_JSON_PATH = os.path.join(DATASETS_PATH, 'keyboard.json')

# %%
# Add my dataset
import json

new_entry_key = "keyboard"
new_entry_value = {
    'file_name': 'keyboard.json',
    'formatting': 'sharegpt',
    'columns': {
        'messages': 'messages',
        'videos': 'videos',
        'audios': 'audios'
    },
    'tags': {
        'role_tag': 'role',
        'content_tag': 'content',
        'user_tag': 'user',
        'assistant_tag': 'assistant'
    }
}

with open(DATASET_INFO_PATH, 'r') as f:
    data = json.load(f)

data[new_entry_key] = new_entry_value

with open(DATASET_INFO_PATH, 'w') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

# %%
# Copy videos
# !rm -rf {DATASETS_PATH}/keyboard_videos
# !mkdir -p {DATASETS_PATH}/keyboard_videos

# %%
# !rsync -r --include='*.mp4' {AUG_DIR}/../train/ {DATASETS_PATH}/keyboard_videos/

# %%
# !rsync -r --include='*.mp4' {AUG_DIR}/ {DATASETS_PATH}/keyboard_videos/

# %% [markdown]
# ```
# parallel --bar -j32 \
#   ffmpeg -y -i {} -vn -acodec pcm_s16le -ar 16000 -ac 1 {.}.wav \
#   ::: *.mp4
# ```
# Use this to convert all .mp4 to .wav

# %%
# %%bash
# cd LLaMA-Factory/data/keyboard_videos
# parallel --bar -j32 \
#   ffmpeg -y -i {} -vn -acodec pcm_s16le -ar 16000 -ac 1 {.}.wav \
#   ::: *.mp4
# Out:
# sh: /dev/tty: Device not configured
# sh: /dev/tty: Device not configured
# 0% 0:27p_4.mp4                                                          520=0s 0.crop_4.mp4                                                      ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.84, start: 0.000000, bitrate: 1121 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 818 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 188 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600000950000] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087648%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=51.6x
# sh: /dev/tty: Device not configured
# sh: /dev/tty: Device not configured
# 0% 1:27519=0s 0.crop_4.mp4                                                      ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_4.aug_4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.83, start: 0.000000, bitrate: 1600 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1383 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 188 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_4.aug_4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x60000353c240] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087648%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=62.7x
# 0% 2:27518=0s 0.crop_4.mp4                                                     46512 ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.94, start: 0.000000, bitrate: 1065 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 835 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_3.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600001508000] video:0KiB audio:86KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.088701%
# size=      86KiB time=00:00:02.74 bitrate= 256.2kbits/s speed=51.8x
# 0% 3:27517.mp4                                                          7=0s 0.crop_4.mp4                                                      ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_3.aug_3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.83, start: 0.000000, bitrate: 1733 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1526 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_3.aug_3.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000018bc000] video:0KiB audio:86KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.088701%
# size=      86KiB time=00:00:02.74 bitrate= 256.2kbits/s speed=50.3x
# 0% 4:09302.mp4                                                          27516=0s 0.crop_4.mp4                                                      ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.84, start: 0.000000, bitrate: 1121 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 818 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 188 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600002e60000] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087648%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=47.9x
# 0% 5:27515=0s 0.crop_4.mp4                                                                                                ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_2.aug_2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.83, start: 0.000000, bitrate: 1651 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1434 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 188 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_2.aug_2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x60000130c000] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087648%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=47.3x
# 0% 6:27514=0s 0.crop_4.mp4                                                                                                    ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.78, start: 0.000000, bitrate: 1152 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 818 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600002158000] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087576%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=67.7x
# 0% 7:27513=0s 0.crop_4.mp4                                                                           ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_1.aug_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.78, start: 0.000000, bitrate: 1641 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1438 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_1.aug_1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000039f0240] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087576%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=79.6x
# 0% 8:27512=0s 0.crop_4.mp4                                                                               ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.78, start: 0.000000, bitrate: 1152 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 818 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000011a0000] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087576%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=71.2x
# 0% 9:27511=0s 0.crop_4.mp4                                                      ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.crop_0.aug_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:02.78, start: 0.000000, bitrate: 1807 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1606 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.crop_0.aug_0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003bec000] video:0KiB audio:87KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.087576%
# size=      87KiB time=00:00:02.78 bitrate= 256.2kbits/s speed=47.6x
# 0% 10:27510=0s 0.crop_4.mp4                                                        ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.aug_31.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:03.15, start: 0.000000, bitrate: 1686 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1495 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.aug_31.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000025780c0] video:0KiB audio:99KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.077202%
# size=      99KiB time=00:00:03.15 bitrate= 256.2kbits/s speed=53.5x
# 0% 11:27509=0s 0.crop_4.mp4                                                  302325581   ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.aug_30.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:03.15, start: 0.000000, bitrate: 1592 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1400 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.aug_30.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x6000011b8000] video:0KiB audio:99KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.077202%
# size=      99KiB time=00:00:03.15 bitrate= 256.2kbits/s speed=52.6x
# 0% 12:27508=0s 0.crop_4.mp4                                                     ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.aug_29.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:03.15, start: 0.000000, bitrate: 1622 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1430 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.aug_29.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003c1c000] video:0KiB audio:99KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.077202%
# size=      99KiB time=00:00:03.15 bitrate= 256.2kbits/s speed=51.9x
# .0472383720930233.mp4                                                          0% 13:27507=0s 0.crop_4.mp4                                                     ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.aug_28.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:03.15, start: 0.000000, bitrate: 1583 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1391 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.aug_28.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003fc43c0] video:0KiB audio:99KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.077202%
# size=      99KiB time=00:00:03.15 bitrate= 256.2kbits/s speed=60.4x
# 0930232558.mp4                                                          % 14:27506=0s 0.crop_4.mp4                                                     ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0.aug_27.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:03.15, start: 0.000000, bitrate: 1669 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1477 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 187 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '0.aug_27.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x60000309c000] video:0KiB audio:99KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.077202%
# size=      99KiB time=00:00:03.15 bitrate= 256.2kbits/s speed=73.1x
# 0% 15:2754.mp4                                                          05=0s 0.crop_4.mp4                                                     ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
# ...
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600000b98000] video:0KiB audio:276KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.027599%
# size=     276KiB time=00:00:08.83 bitrate= 256.1kbits/s speed= 616x
# 0% 226:27294=8m23s 104.aug_26.mp4                                        4                                                                                                                                                                                                                                                                                                           ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '104.aug_21.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:08.83, start: 0.000000, bitrate: 1523 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1317 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 197 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '104.aug_21.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600003704000] video:0KiB audio:276KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.027599%
# size=     276KiB time=00:00:08.83 bitrate= 256.1kbits/s speed= 201x
# 0% 227:27293=8m23s 104.aug_27.mp4                                               91   1162791ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '104.aug_24.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:08.83, start: 0.000000, bitrate: 1481 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 1274 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 197 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '104.aug_24.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x60000038c480] video:0KiB audio:276KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.027599%
# size=     276KiB time=00:00:08.83 bitrate= 256.1kbits/s speed= 239x  IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# 0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '105.crop_1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600002d38000] video:0KiB audio:169KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.044981%
# size=     169KiB time=00:00:05.41 bitrate= 256.1kbits/s speed= 226x
# 1% 290:27230=8m23s 105.crop_5.aug_5.mp4                                                              ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '105.crop_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:06.01, start: 0.000000, bitrate: 1185 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 859 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 193 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '105.crop_0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x600000010000] video:0KiB audio:184KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.041492%
# size=     184KiB time=00:00:05.87 bitrate= 256.1kbits/s speed= 238x
# 1% 291:27229=8m23s 105.crop_9.aug_9.mp4                                         127906976767 503 sec 105.crop_6.mp4                                                      1% 291:27229=8m23s 105.crop_6.mp4                                                105.crop_7.aug_7.mp4                                                1:27229=8m23s 105.crop_7.aug_7.mp4                                         p_7.mp4                                                      8m23s 105.crop_7.mp4                                               8.mp4                                                5.crop_8.aug_8.mp4                                                                                      .mp4                                                                                    p4                                         ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '105.crop_5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf61.7.100
#   Duration: 00:00:05.93, start: 0.000000, bitrate: 1204 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 640x480 [SAR 1:1 DAR 4:3], 857 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#       Metadata:
#         handler_name    : VideoHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 193 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '105.crop_5.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf61.7.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#       Metadata:
#         handler_name    : SoundHandler
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.19.101 pcm_s16le
# [out#0/wav @ 0x60000394c480] video:0KiB audio:182KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.041896%
# size=     182KiB time=00:00:05.81 bitrate= 256.1kbits/s speed= 234x
# 1% 292:27228=8m23s 105.crop_9.mp4                                                                                ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with clang version 18.1.8
#   configuration: --prefix=/opt/homebrew/anaconda3/envs/185FinalProj --cc=arm64-apple-darwin20.0.0-clang --cxx=arm64-apple-darwin20.0.0-clang++ --nm=arm64-apple-darwin20.0.0-nm --ar=arm64-apple-darwin20.0.0-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --enable-cross-compile --arch=arm64 --target-os=darwin --cross-prefix=arm64-apple-darwin20.0.0- --host-cc=/Users/runner/miniforge3/conda-bld/ffmpeg_1743376098333/_build_env/bin/x86_64-apple-darwin13.4.0-clang --enable-neon --disable-gnutls --enable-libvpx --enable-libass --enable-pthreads --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libmp3lame --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libvorbis --enable-libopus --enable-librsvg --enable-ffplay --pkg-config=

# %%
# !rsync -avz LLaMA-Factory/data/keyboard_videos vast:/workspace/1training/LLaMA-Factory/data/keyboard_videos/

# %%
len(final_samples)
# Out:
# 10846

# %%
# %%bash
# cd LLaMA-Factory/data/keyboard_videos
# echo "Checking for corrupted or unreadable .mp4/.wav files..."
# echo "Writing plain paths to bad.txt"
# echo "----"
#
# # Clear output file
# : > bad.txt
#
# # Function to validate a single file
# check_file() {
#   file="$1"
#   duration=$(ffprobe -v error -show_entries format=duration \
#     -of default=noprint_wrappers=1:nokey=1 "$file" 2>/dev/null)
#
#   # If ffprobe fails outright
#   if [ $? -ne 0 ]; then
#     echo "$file" >> bad.txt
#     return
#   fi
#
#   # If duration is not a valid number (e.g., "N/A")
#   if ! [[ "$duration" =~ ^[0-9]+(\.[0-9]+)?$ ]]; then
#     echo "$file" >> bad.txt
#     return
#   fi
#
#   # If duration is 0 or less
#   duration_int=${duration%.*}
#   if [ "$duration_int" -le 0 ]; then
#     echo "$file" >> bad.txt
#   fi
# }
#
# # Export function for parallel
# export -f check_file
#
# # Run checks on all visible .mp4/.wav files in parallel with a progress bar
# find . -type f \( -iname "*.mp4" -o -iname "*.wav" \) ! -iname ".*" \
#   | parallel -j 16 --bar check_file {}
# cp bad.txt ../../../
# Out:
# Checking for corrupted or unreadable .mp4/.wav files...
# Writing plain paths to bad.txt
# ----
# sh: /dev/tty: Device not configured
# sh: /dev/tty: Device not configured
# 0% 0:27.crop_7.mp4                                                          0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                        520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                                                                                       520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                        520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                        520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                        520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                        520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                        520=0s ./265.crop_7.mp4                                                  7.mp4                                                                                                                                                                                        m0% 0:27520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  sh: /dev/tty: Device not configured
# sh: /dev/tty: Device not configured
# 0% 0:27.crop_7.mp4                                                      520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  sh: /dev/tty: Device not configured
# sh: /dev/tty: Device not configured
# 0% 0:27.crop_7.mp4                                                      520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  sh: /dev/tty: Device not configured
# sh: /dev/tty: Device not configured
# 0% 55:27465=0s ./482.crop_5.mp4                                                 .crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  520=0s ./265.crop_7.mp4                                                  7.mp4                                                      s ./265.crop_7.mp4                                                  561270 sec ./61.aug_21.mp4                                                       0% 4:27516=0s ./61.aug_21.mp4                                                   ./61.aug_21.mp4                                                        5:27515=0s ./61.aug_21.mp4                                                   ug_21.mp4                                                       14=0s ./61.aug_21.mp4                                                   mp4                                                       ./61.aug_21.mp4                                                                                                       ug_21.mp4                                                    sec ./61.aug_21.mp4                                                       0% 10:27510=0s ./61.aug_21.mp4                                                  /61.aug_21.mp4                                                       11:27509=0s ./61.aug_21.mp4                                                  g_21.mp4                                                       08=0s ./61.aug_21.mp4                                                  p4                                                       ./61.aug_21.mp4                                                                                                     ug_21.mp4                                                                                               mp4                                                                                                                                                                                                                  99555111662270 sec ./329.aug_29.mp4                                                      0% 21:27499=0s ./329.aug_29.mp4                                                 33840 sec ./260.aug_13.mp4                                                      0% 24:27496=0s ./260.aug_13.mp4                                                 44950 sec ./172.aug_17.mp4                                                      0% 26:27494=0s ./172.aug_17.mp4                                                 5510 sec ./163.aug_15.mp4                                                      0% 27:27493=0s ./163.aug_15.m
# %%
# !cat bad.txt | wc -l
# Out:
#     1830

# %%
bad_files = []
with open('bad.txt', 'r') as f:
    for line in f:
        bad_files.append(line.strip().replace('./', ''))
bad_files[:10]
# Out:
# ['465.aug_10.mp4',
#  '465.aug_11.mp4',
#  '465.aug_12.mp4',
#  '465.aug_14.mp4',
#  '465.aug_13.mp4',
#  '465.aug_15.mp4',
#  '465.aug_16.mp4',
#  '465.aug_17.mp4',
#  '465.aug_18.mp4',
#  '465.aug_19.mp4']

# %%
import os

json_samples = []
skipped = 0
for sample in final_samples:
    file_name = os.path.basename(sample['file_path'])
    new_file_path = f'{DATASETS_PATH}/keyboard_videos/{file_name}'
    if not os.path.exists(new_file_path):
        print(f"Path {new_file_path} not found, skipping")
        continue

    if '248' in new_file_path:
        print(new_file_path)

    if len(sample['text']) < 10:
        continue

    video_rel_path = new_file_path.replace('LLaMA-Factory/data/', '')
    audio_rel_path = video_rel_path.replace('.mp4', '.wav')

    if os.path.basename(video_rel_path) in bad_files or os.path.basename(audio_rel_path) in bad_files:
        skipped += 1
        continue

    json_sample = {
        'messages': [
            {
                'content': '<video><audio>What exact string is typed in this overhead recording of typing on a MacBook keyboard at an upside down view?',
                'role': 'user'
            },
            {
                'content': f"The typed string is: {sample['text']}",
                'role': 'assistant'
            }
        ],
        'videos': [
            video_rel_path
        ],
        'audios': [
            audio_rel_path
        ]
    }
    json_samples.append(json_sample)

with open(DATASET_JSON_PATH, 'w') as f:
    json.dump(json_samples, f, ensure_ascii=False, indent=2)

DATASET_JSON_PATH, skipped, len(json_samples), json_samples[0]
# Out:
# ('LLaMA-Factory/data/keyboard.json',
#  0,
#  20374,
#  {'messages': [{'content': '<video><audio>What exact string is typed in this overhead recording of typing on a MacBook keyboard at an upside down view?',
#     'role': 'user'},
#    {'content': 'The typed string is: This is a change of nuance.',
#     'role': 'assistant'}],
#   'videos': ['keyboard_videos/681.mp4'],
#   'audios': ['keyboard_videos/681.wav']})

# %% [markdown]
# # EVAL SET

# %%
# !cp -r ../0data_collection/keystroke-typing-videos/test/* LLaMA-Factory/data/keyboard_videos/

# %%
eval_samples = dataset['test']
eval_samples[:2]
# Out:
# {'file_name': ['248.mp4', '434.mp4'],
#  'text': ['Imports fell by 9.4 pct in February from January.',
#   'Humana said the rights expire March 4, 1997, unless redeemed earlier.'],
#  'duration_sec': [5.1, 7.833333],
#  'keystrokes': [[{'event': 'down', 'key': 'Shift_L', 'timestamp_ms': 0},
#    {'event': 'down', 'key': 'I', 'timestamp_ms': 105},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 261},
#    {'event': 'down', 'key': 'p', 'timestamp_ms': 414},
#    {'event': 'down', 'key': 'o', 'timestamp_ms': 532},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 5418},
#    {'event': 'down', 'key': 'u', 'timestamp_ms': 5513},
#    {'event': 'down', 'key': 'n', 'timestamp_ms': 5656},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 5800},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 5823},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 6014},
#    {'event': 'down', 'key': 's', 'timestamp_ms': 6164},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 6229},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 6335},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6390},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 6552},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6701},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 6854},
#    {'event': 'down', 'key': 'm', 'timestamp_ms': 6941},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7021},
#    {'event': 'down', 'key': 'd', 'timestamp_ms': 7180},
#    {'event': 'down', 'key': 'space', 'timestamp_ms': 7286},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7351},
#    {'event': 'down', 'key': 'a', 'timestamp_ms': 7428},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7550},
#    {'event': 'down', 'key': 'l', 'timestamp_ms': 7664},
#    {'event': 'down', 'key': 'i', 'timestamp_ms': 7808},
#    {'event': 'down', 'key': 'e', 'timestamp_ms': 7856},
#    {'event': 'down', 'key': 'r', 'timestamp_ms': 7910},
#    {'event': 'down', 'key': 'period', 'timestamp_ms': 8023}]],
#  'actual_fps': [29.37297829151598, 29.4215430822555]}

# %%
json_samples = []
for sample in eval_samples:
    file_name = sample['file_name']
    new_file_path = f'{DATASETS_PATH}/keyboard_videos/{file_name}'
    if not os.path.exists(new_file_path):
        raise ValueError(f"Path {new_file_path} not found, skipping")

    video_rel_path = new_file_path.replace('LLaMA-Factory/data/', '')
    audio_rel_path = video_rel_path.replace('.mp4', '.wav')

    json_sample = {
        'messages': [
            {
                'content': '<video><audio>What exact string is typed in this overhead recording of typing on a MacBook keyboard at an upside down view?',
                'role': 'user'
            },
            {
                'content': f"The typed string is: {sample['text']}",
                'role': 'assistant'
            }
        ],
        'videos': [
            video_rel_path
        ],
        'audios': [
            audio_rel_path
        ]
    }
    json_samples.append(json_sample)

with open('LLaMA-Factory/data/keyboard_eval.json', 'w') as f:
    json.dump(json_samples, f, ensure_ascii=False, indent=2)

# %%
# Add my dataset
import json

new_entry_key = "keyboard_eval"
new_entry_value = {
    'file_name': 'keyboard_eval.json',
    'formatting': 'sharegpt',
    'columns': {
        'messages': 'messages',
        'videos': 'videos',
        'audios': 'audios'
    },
    'tags': {
        'role_tag': 'role',
        'content_tag': 'content',
        'user_tag': 'user',
        'assistant_tag': 'assistant'
    }
}

with open(DATASET_INFO_PATH, 'r') as f:
    data = json.load(f)

data[new_entry_key] = new_entry_value

with open(DATASET_INFO_PATH, 'w') as f:
    json.dump(data, f, ensure_ascii=False, indent=2)
